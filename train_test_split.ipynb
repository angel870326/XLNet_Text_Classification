# %% [markdown]
# <a href="https://colab.research.google.com/github/angel870326/XLNet_Text_Classification/blob/main/train_test_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > 2022.05.15 Ssu-Yun Wang<br/>
# [Github @angel870326](https://github.com/angel870326)
#
# # **Training Data Slip into Training and Testing Set**
#
# ### Contents:
#
# *   品類
# *   品牌

# %%
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **品類**
#
#
# ---

# %%
# Raw dataset
product_train_raw = pd.read_csv('/content/drive/MyDrive/碩一下/金融科技/麻布數據/資料檔/品類_clean.csv')
product_train_raw = product_train_raw.dropna()
product_train_raw.head()
# Out:
#    Unnamed: 0                     name product       clean_name
# 0           0  r視舒坦單支裝人工淚液點眼液0.5ml24支入    人工淚液  r視舒坦單支裝人工淚液點眼液入
# 1           1               優麗舒點眼液15ml    人工淚液           優麗舒點眼液
# 2           2              (r)視舒坦單支裝人工    人工淚液        r視舒坦單支裝人工
# 3           3                rohto乾眼淚液    人工淚液        rohto乾眼淚液
# 4           4        r參天柔潤人工淚液點眼液5ml4入    人工淚液     r參天柔潤人工淚液點眼液

# %%
# Clean dataset
product_train_data = {'id': range(1, len(product_train_raw) + 1),
              'name': product_train_raw['name'],
              'clean_name': product_train_raw['clean_name'],
              'product': product_train_raw['product']}
product_train = pd.DataFrame(product_train_data)
product_train
# Out:
#           id                           name             clean_name product
# 0          1        r視舒坦單支裝人工淚液點眼液0.5ml24支入        r視舒坦單支裝人工淚液點眼液入    人工淚液
# 1          2                     優麗舒點眼液15ml                 優麗舒點眼液    人工淚液
# 2          3                    (r)視舒坦單支裝人工              r視舒坦單支裝人工    人工淚液
# 3          4                      rohto乾眼淚液              rohto乾眼淚液    人工淚液
# 4          5              r參天柔潤人工淚液點眼液5ml4入           r參天柔潤人工淚液點眼液    人工淚液
# ...      ...                            ...                    ...     ...
# 91914  91908           mdmmd微醺心機漸層腮紅-玫瑰瑪格麗特   mdmmd微醺心機漸層腮紅-玫瑰瑪格麗特      腮紅
# 91915  91909               mdmmd微醺心機漸層腮紅-橙酒       mdmmd微醺心機漸層腮紅-橙酒      腮紅
# 91916  91910             倫敦芮魅叛逆玩色腮紅盤005微醺酒紅     倫敦芮魅叛逆玩色腮紅盤005微醺酒紅      腮紅
# 91917  91911           palladio柔光幻彩貝殼腮紅微醺蜜桃   palladio柔光幻彩貝殼腮紅微醺蜜桃      腮紅
# 91918  91912  【韓國e-glips】粉嫩微醺美肌花瓣腮紅4g(6色可選)  韓國e-glips粉嫩微醺美肌花瓣腮紅可選      腮紅
#
# [91912 rows x 4 columns]

# %%
# product counter
product_count = Counter(product_train['product'].values)
product_count
# Out:
# Counter({'bb霜': 113,
#          'cc霜': 63,
#          'dd霜': 13,
#          'rtd調酒': 590,
#          '中式香腸': 287,
#          '乳酸菌': 41,
#          '人工淚液': 114,
#          '保久乳': 231,
#          '保溫杯': 3,
#          '保險套': 578,
#          '修容': 164,
#          '健腹器': 15,
#          '優格': 532,
#          '優酪乳': 341,
#          '兒童漱口水': 107,
#          '兒童牙刷': 404,
#          '兒童牙膏': 312,
#          '其他地墊(家用)': 182,
#          '冰箱': 216,
#          '冷氣/冷暖空調': 82,
#          '前導精華': 16,
#          '化妝水': 882,
#          '即溶咖啡': 683,
#          '即食雞胸': 82,
#          '即飲咖啡': 408,
#          '即飲奶茶': 538,
#          '即飲烏龍茶': 106,
#          '即飲無糖茶': 251,
#          '即飲紅茶': 587,
#          '即飲綠茶': 406,
#          '卸妝乳': 153,
#          '卸妝凝膠': 121,
#          '卸妝棉': 280,
#          '卸妝水': 403,
#          '卸妝油': 249,
#          '卸妝濕巾': 17,
#          '卸妝霜': 41,
#          '卸妝露': 10,
#          '卸甲液': 3,
#          '原味牛乳': 14,
#          '吸塵器': 572,
#          '吹風機': 451,
#          '咖啡機': 134,
#          '咖啡豆': 259,
#          '唇彩': 67,
#          '唇彩盤': 13,
#          '唇線筆': 23,
#          '唇膏': 1130,
#          '唇蜜': 170,
#          '唇釉': 383,
#          '唇露': 91,
#          '啞鈴/槓鈴': 62,
#          '啤酒': 2000,
#          '奶瓶': 235,
#          '妝前乳/隔離霜': 569,
#          '媽媽奶粉': 26,
#          '媽媽茶(哺乳茶)': 9,
#          '嬰幼乳液': 6,
#          '嬰幼手推車': 6,
#          '安全汽座': 52,
#          '巧拼地墊': 19,
#          '常溫醬包': 1345,
#          '平板電腦': 156,
#          '廚房紙巾': 215,
#          '微波爐': 235,
#          '快煮壺': 260,
#          '快煮麵/乾拌麵': 561,
#          '成人奶粉': 453,
#          '成人牙刷': 1293,
#          '成人牙膏': 2069,
#          '成人紙尿褲': 239,
#          '成長幼兒奶粉': 142,
#          '指甲油': 872,
#          '按摩椅': 22,
#          '掃地機': 182,
#          '排油煙機': 34,
#          '擴香瓶': 203,
#          '收納櫃': 299,
#          '智慧型手機': 811,
#          '智慧錶': 213,
#          '杏仁奶': 53,
#          '果汁機': 78,
#          '染眉膏': 133,
#          '柔軟精': 355,
#          '桌上電腦': 63,
#          '棉條': 256,
#          '棉褲/安睡褲': 134,
#          '椰奶': 30,
#          '槓片': 3,
#          '機能牛乳': 67,
#          '氣泡水': 502,
#          '氣炸鍋': 90,
#          '水路/健行鞋': 4,
#          '沐浴乳': 3037,
#          '洗碗機': 23,
#          '洗衣機': 320,
#          '洗衣球': 458,
#          '洗衣皂': 143,
#          '洗衣粉': 350,
#          '洗衣精': 2094,
#          '洗面乳': 2844,
#          '洗髮精': 3677,
#          '洗髮精(嬰幼童/孕婦)': 245,
#          '消毒鍋': 33,
#          '液晶電視': 322,
#          '淨水器/濾水器': 174,
#          '湯圓': 139,
#          '溫奶器': 17,
#          '滑鼠': 1135,
#          '滴雞精': 203,
#          '潤髮乳': 698,
#          '濕紙巾': 1604,
#          '濾掛/耳掛咖啡': 378,
#          '火鍋料': 291,
#          '烘碗機': 116,
#          '烘衣機/乾衣機': 64,
#          '烤箱': 207,
#          '烤肉架': 17,
#          '熱水器': 96,
#          '燕麥奶': 206,
#          '狗乾糧罐頭': 1412,
#          '狗零食': 459,
#          '珪藻土地墊': 138,
#          '瑜珈墊': 33,
#          '瓦斯爐(廚房用)': 57,
#          '瓦斯爐(攜帶式)': 70,
#          '甲油膠': 20,
#          '甲片/甲貼': 229,
#          '益生菌': 387,
#          '眉筆': 854,
#          '眉粉': 131,
#          '眉膠筆': 65,
#          '眼唇卸妝': 160,
#          '眼影刷/棒': 194,
#          '眼影打底': 23,
#          '眼影盤': 706,
#          '眼影筆': 42,
#          '眼影蜜': 25,
#          '眼影霜': 16,
#          '眼線液': 250,
#          '眼線液筆': 136,
#          '眼線筆': 191,
#          '眼線膠筆': 263,
#          '眼部精華': 71,
#          '眼霜': 306,
#          '睡袋': 253,
#          '睫毛膏': 420,
#          '碳酸飲料': 1003,
#          '礦泉水': 1065,
#          '筆記型電腦': 287,
#          '米漿/豆米漿': 126,
#          '粉底液': 774,
#          '粉餅': 678,
#          '精油': 174,
#          '精華油': 78,
#          '精華液': 795,
#          '維他命b': 472,
#          '維他命b+c': 42,
#          '維他命c': 266,
#          '維他命d': 92,
#          '維他命e': 39,
#          '維他命飲料': 254,
#          '羊乳': 21,
#          '腮紅': 368,
#          '膠原蛋白': 227,
#          '臉部乳液': 886,
#          '芳香豆': 224,
#          '菸': 1818,
#          '葉酸': 56,
#          '葉黃素': 618,
#          '薑黃': 164,
#          '蜜粉': 488,
#          '衛生棉': 662,
#          '衛生紙': 1061,
#          '西式香腸': 98,
#          '調味牛乳': 361,
#          '調味豆漿': 58,
#          '調理機': 73,
#          '護唇精華': 49,
#          '護唇膏': 1183,
#          '護手霜': 975,
#          '護髮乳': 1803,
#          '豆奶/豆乳': 171,
#          '豆漿/黑豆漿': 344,
#          '貓乾糧罐頭': 1999,
#          '貓零食': 340,
#          '跑步機': 35,
#          '身體乳液': 438,
#          '速食麵/泡麵': 2360,
#          '運動/機能服': 2074,
#          '運動鞋': 2005,
#          '遮瑕液': 65,
#          '遮瑕盤': 32,
#          '遮瑕筆': 59,
#          '遮瑕膏': 175,
#          '遮瑕蜜': 39,
#          '醬油類': 847,
#          '野餐墊': 58,
#          '鍋具': 1530,
#          '鍵盤': 485,
#          '防曬': 494,
#          '除濕機': 566,
#          '雞精': 201,
#          '電子鍋': 194,
#          '電暖器': 1549,
#          '電熱水瓶': 217,
#          '電磁爐': 112,
#          '電視遊戲機': 151,
#          '電鍋': 189,
#          '電風扇': 199,
#          '面膜': 1872,
#          '面霜/乳霜': 1214,
#          '香氛機': 47,
#          '香氛蠟燭': 102,
#          '鮮乳': 685,
#          '麥片穀類': 637})

# %%
# Train test split
product_training, product_testing = train_test_split(product_train, test_size=0.2, random_state=42)
product_training
# Out:
#           id                           name              clean_name  product
# 46958  46952                    虎牌啤酒485ml四入                  虎牌啤酒四入       啤酒
# 66355  66349                  虎牌jai-g55r電子鍋           虎牌jai-g55r電子鍋      電子鍋
# 76624  76618                妝點甜心遮瑕蜜cannelle         妝點甜心遮瑕蜜cannelle      遮瑕蜜
# 85916  85910      【鮮一杯】衣索匹亞西達摩濾掛咖啡(10gx10入)         鮮一杯衣索匹亞西達摩濾掛咖啡x  濾掛/耳掛咖啡
# 84551  84545      irocksk75m淡雅粉白色背光機械式鍵盤-紅軸  irocksk淡雅粉白色背光機械式鍵盤-紅軸       鍵盤
# ...      ...                            ...                     ...      ...
# 6272    6266      【桂格】高鐵高鈣奶粉7倍膠原蛋白(1500g/罐)         桂格高鐵高鈣奶粉7倍膠原蛋白罐     成人奶粉
# 54893  54887  【weet-bix】澳洲全穀麥片麥香高鈣375g(3入組)     weet-bix澳洲全穀麥片麥香高鈣組     麥片穀類
# 76827  76821               oatly原味燕麥奶1000ml              oatly原味燕麥奶      燕麥奶
# 867      861        bioneo百妮玻尿酸保濕化妝水凝露350ml      bioneo百妮玻尿酸保濕化妝水凝露      化妝水
# 15802  15796                        麗仕沐浴乳薰衣                 麗仕沐浴乳薰衣      沐浴乳
#
# [73529 rows x 4 columns]

# %%
product_training.to_csv('/content/drive/MyDrive/碩一下/金融科技/麻布數據/資料檔/category_train.csv', index=False)
product_testing.to_csv('/content/drive/MyDrive/碩一下/金融科技/麻布數據/資料檔/category_test.csv', index=False)

# %% [markdown]
# ## **品牌**
#
#
# ---

# %%
# Raw dataset
brand_train_raw = pd.read_csv('/content/drive/MyDrive/碩一下/金融科技/麻布數據/資料檔/品牌_clean.csv')
brand_train_raw = brand_train_raw.dropna()
brand_train_raw.head()
# Out:
#    Unnamed: 0                                            name         brand  \
# 0           0                                    妮傲絲翠果酸深層保養乳液   neo-tec妮傲絲翠
# 1           1  neostrata妮傲絲翠果酸深層保養乳液(200ml)aha15【小三美日】d082024   neo-tec妮傲絲翠
# 2           2                      妮傲絲翠高效neotec物理性潤色防曬霜50mlsp  neo-tec 妮傲絲翠
# 3           3      【妮傲絲翠】neostrata果酸煥膚之王經典乳液(15%)200ml(2入特惠組)   neo-tec妮傲絲翠
# 4           4                                    妮傲絲翠物理性潤色防曬霜  neo-tec 妮傲絲翠
#
#    clean_brand                       clean_name
# 0  妮傲絲翠neo-tec                     妮傲絲翠果酸深層保養乳液
# 1  妮傲絲翠neo-tec  neostrata妮傲絲翠果酸深層保養乳液aha15小三美日d
# 2  妮傲絲翠neo-tec           妮傲絲翠高效neotec物理性潤色防曬霜sp
# 3  妮傲絲翠neo-tec          妮傲絲翠neostrata果酸煥膚之王經典乳液
# 4  妮傲絲翠neo-tec                     妮傲絲翠物理性潤色防曬霜

# %%
# Clean dataset
brand_train_data = {'id': range(1, len(brand_train_raw) + 1),
              'name': brand_train_raw['name'],
              'brand': brand_train_raw['brand'],
              'clean_name': brand_train_raw['clean_name'],
              'clean_brand': brand_train_raw['clean_brand']}
brand_train = pd.DataFrame(brand_train_data)
brand_train
# Out:
#           id                                            name         brand  \
# 0          1                                    妮傲絲翠果酸深層保養乳液   neo-tec妮傲絲翠
# 1          2  neostrata妮傲絲翠果酸深層保養乳液(200ml)aha15【小三美日】d082024   neo-tec妮傲絲翠
# 2          3                      妮傲絲翠高效neotec物理性潤色防曬霜50mlsp  neo-tec 妮傲絲翠
# 3          4      【妮傲絲翠】neostrata果酸煥膚之王經典乳液(15%)200ml(2入特惠組)   neo-tec妮傲絲翠
# 4          5                                    妮傲絲翠物理性潤色防曬霜  neo-tec 妮傲絲翠
# ...      ...                                             ...           ...
# 70041  70035                           386680@h唯浴雅薰衣草香洗衣精4kg           唯浴雅
# 70042  70036                                 華菱清淨除濕機hpws-40k            華菱
# 70043  70037                          【台鹽生技】金盞花葉黃素5盒組(30顆/盒)            台塩
# 70044  70038                            上元14吋碳素燈電暖器型號:sy-403            上元
# 70045  70039                            【一午一食】臻純粹滴雞精(10入/盒裝)          一午一食
#
#                             clean_name  clean_brand
# 0                         妮傲絲翠果酸深層保養乳液  妮傲絲翠neo-tec
# 1      neostrata妮傲絲翠果酸深層保養乳液aha15小三美日d  妮傲絲翠neo-tec
# 2               妮傲絲翠高效neotec物理性潤色防曬霜sp  妮傲絲翠neo-tec
# 3              妮傲絲翠neostrata果酸煥膚之王經典乳液  妮傲絲翠neo-tec
# 4                         妮傲絲翠物理性潤色防曬霜  妮傲絲翠neo-tec
# ...                                ...          ...
# 70041                       唯浴雅薰衣草香洗衣精          唯浴雅
# 70042                  華菱清淨除濕機hpws-40k           華菱
# 70043                     台鹽生技金盞花葉黃素組盒           台塩
# 70044                         上元碳素燈電暖器           上元
# 70045                     一午一食臻純粹滴雞精盒裝         一午一食
#
# [70039 rows x 5 columns]

# %%
# brand counter
brand_count = Counter(brand_train['brand'].values)
brand_count
# Out:
# Counter({'neo-tec妮傲絲翠': 8,
#          'neo-tec 妮傲絲翠': 4,
#          '飛利浦 philips': 180,
#          'senka 專科': 437,
#          'refine': 1,
#          'fancl 芳珂': 2,
#          'fancl': 4,
#          '紅牛 red bull': 58,
#          "i'm meme": 95,
#          '富維克 volvic': 32,
#          'nivea 妮維雅': 296,
#          '妮維雅 nivea': 1,
#          'lion 獅王': 218,
#          '獅王lion': 107,
#          'lion獅王': 3,
#          '獅王 lion': 8,
#          'kissme 奇士美': 217,
#          'kissme': 5,
#          'curel 珂潤': 148,
#          '珂潤 curel': 8,
#          'sana 莎娜': 82,
#          'mentholatum 曼秀雷敦': 549,
#          '曼秀雷敦 mentholatum': 28,
#          'chicco': 33,
#          '萬能媽媽 wonder mama': 11,
#          'carmex 小蜜媞': 34,
#          '蘋果 apple': 489,
#          '國際牌 panasonic': 493,
#          'panasonic': 53,
#          'kirin': 511,
#          'my beauty diary 我的美麗日記': 92,
#          'essence cosmetics 艾森絲': 351,
#          'cezanne': 111,
#          'nailholic': 246,
#          'eupa': 3,
#          '優柏 eupa': 3,
#          '耐吉 nike': 769,
#          'olay 歐蕾': 106,
#          '艾瑪花園 amma garden': 62,
#          'amma garden 艾瑪花園': 1,
#          'sowa sowa': 1,
#          'lcb藍帶廚坊': 21,
#          'champion': 100,
#          'heme 喜蜜': 158,
#          'heme': 128,
#          '東元 teco': 102,
#          'media 媚點': 482,
#          '伊萊克斯 electrolux': 58,
#          'ocean spring': 16,
#          '小米 xiaomi': 9,
#          '特福 tefal': 211,
#          '法國特福 tefal': 3,
#          '三星 samsung': 301,
#          'revlon 露華濃': 80,
#          'za': 398,
#          'm.a.c': 261,
#          '麗奇 reach': 52,
#          'venus marble': 1,
#          'skechers': 255,
#          'ucc': 177,
#          '愛仕達 asd': 67,
#          '華碩 asus': 116,
#          '法國皇家 royal': 16,
#          '御皇居 royal': 1,
#          'adidas 愛迪達': 44,
#          'adidas': 724,
#          '愛迪達 adidas': 5,
#          'meko 時尚美妝': 5,
#          '華米 amazfit': 58,
#          'lily&color': 29,
#          'cellina 雪芙蘭': 281,
#          '雪芙蘭 cellina': 21,
#          'yuskin 悠斯晶': 49,
#          'kanebo 佳麗寶': 70,
#          'gatsby': 85,
#          '維他露p': 61,
#          'cetaphil 舒特膚': 62,
#          'avene 雅漾': 91,
#          'avène 雅漾': 12,
#          'dior 迪奧': 171,
#          'dior': 2,
#          '迪奧 dior': 3,
#          '優格toma-pro': 58,
#          '優格 toma-pro': 51,
#          '卓威 zowie': 8,
#          '鍋寶 cookpower': 163,
#          '黑松 heysong': 223,
#          'lancôme 蘭蔻': 168,
#          'lancome 蘭蔻': 2,
#          'biore 蜜妮': 241,
#          'bioré': 223,
#          '蜜妮biore': 263,
#          '蜜妮 bioré': 25,
#          'gum': 64,
#          'dr.spa': 1,
#          '葛莉思 greens': 74,
#          'puma': 169,
#          'kanebo 佳麗寶-開架式': 10,
#          'e-books': 89,
#          'califia farms': 8,
#          'la mer 海洋拉娜': 17,
#          '阿曼特 armonto': 6,
#          'superfiber': 2,
#          'watsons': 33,
#          'watsons 屈臣氏': 11,
#          '屈臣氏 watsons': 6,
#          '1028': 386,
#          'chic choc 奇可俏可': 12,
#          'milani': 38,
#          '三詩達 sunstar': 43,
#          'cheers': 93,
#          'botanist': 60,
#          'k-palette': 16,
#          '味味a': 54,
#          'go!': 23,
#          '潘婷 pantene': 113,
#          'dell 戴爾': 15,
#          '戴爾dell': 1,
#          'eileen grace 妍霓絲': 5,
#          'origins 品木宣言': 95,
#          'mdmmd 明洞國際': 30,
#          'mdmmd': 56,
#          '聰明狗糧 iq dog': 35,
#          '渴望 orijen': 31,
#          '呂 ryo': 79,
#          'bioderma 貝膚黛瑪': 77,
#          'atunas 歐都納': 15,
#          'la roche posay 理膚寶水': 78,
#          "kiehl's 契爾氏": 213,
#          'tsaio 上山採藥': 59,
#          '上山採藥 tsaio': 14,
#          'illy': 7,
#          '阿q桶麵': 86,
#          '羅技 logitech': 611,
#          '花香5': 40,
#          'ego意高': 6,
#          'hydro balance 水平衡': 69,
#          '水平衡 hydro balance': 25,
#          '聲寶 sampo': 131,
#          'aveeno 艾惟諾': 48,
#          'sunisa 蘇妮薩': 1,
#          'bondi wash': 1,
#          '惜時 seeds': 48,
#          '聖萊西 seeds': 195,
#          'dhc': 166,
#          's+miracle': 12,
#          '日立 hitachi': 114,
#          '希爾思 hills': 77,
#          'maybelline 媚比琳': 635,
#          'dr.hsieh 達特醫': 37,
#          'dr.hsieh達特醫': 5,
#          'dr.hsieh': 2,
#          'grandmother agafia 阿加菲亞老奶奶': 16,
#          '阿加菲亞老奶奶 grandmother agafia': 5,
#          '西莎 cesar': 160,
#          'chifure': 17,
#          '禾聯 heran': 71,
#          "madam jan's": 14,
#          "台塑生醫 dr's formula": 101,
#          "dr's formula 台塑生醫": 4,
#          "台塑生醫dr's formula": 5,
#          "dr's formula": 9,
#          'artis di voce': 39,
#          'parrs': 1,
#          'utena 佑天蘭': 13,
#          'new balance': 364,
#          'kitchenaid': 4,
#          'john masters organics': 3,
#          'hair recipe': 41,
#          'rasto': 22,
#          'under armour': 197,
#          "bhk's": 78,
#          'color club': 34,
#          '強品 chian pin': 20,
#          '美萃 mature': 4,
#          'dejavu': 54,
#          '松木家電 matric': 3,
#          'reebok': 124,
#          'dr.hows': 2,
#          'abc': 10,
#          'realme': 57,
#          '象印 zojirushi': 74,
#          'tcl': 17,
#          'ariel': 168,
#          'converse': 169,
#          'sillymann': 2,
#          'ziaja 齊葉雅': 2,
#          'ziaja': 1,
#          'on the body': 72,
#          'forbelovedone 寵愛之名': 26,
#          'forbelovedone寵愛之名': 37,
#          '施巴 sebamed': 44,
#          'sebamed 施巴': 74,
#          '施巴sebamed': 12,
#          '海德 head': 2,
#          'head 海德': 3,
#          'black monster': 14,
#          '蒂沐蝶 timotei': 36,
#          'timotei': 18,
#          '紐頓 nutram': 27,
#          'catrice 卡翠絲': 243,
#          '樂金 lg': 102,
#          'lg': 15,
#          "paula's choice 寶拉珍選": 24,
#          'numis med 樂美思': 1,
#          "pond's 旁氏": 33,
#          'ardell': 31,
#          '歐樂b': 139,
#          'carome.': 19,
#          'crabtree&evelyn 瑰柏翠': 18,
#          '加好寶 classic pets': 83,
#          '莫比 mobby': 78,
#          'biotherm 碧兒泉': 58,
#          'the saem': 23,
#          'integrate 櫻特芮': 274,
#          'elizabeth arden 伊麗莎白雅頓': 7,
#          'lab series 雅男士': 52,
#          'excel': 144,
#          'sofina 蘇菲娜': 65,
#          'herbacin 德國小甘菊': 47,
#          '奧佳華 ogawa': 1,
#          'sour3': 32,
#          'eva': 5,
#          'bcl': 49,
#          'avalon': 22,
#          'nars': 164,
#          '沛奇 pei ci': 10,
#          'shiseido 資生堂': 144,
#          'shiseido 資生堂東京櫃': 23,
#          'shiseido 資生堂國際櫃': 87,
#          '資生堂 shiseido': 6,
#          'more': 37,
#          "l'erbolario 蕾莉歐": 9,
#          "蕾莉歐 l'erbolario": 1,
#          'poppop': 36,
#          'kose 高絲': 187,
#          'winmax': 82,
#          '艾瑪絲 aromase': 64,
#          '正負零±0': 10,
#          'd program 敏感話題': 57,
#          'whoo 后': 19,
#          '4u2': 50,
#          '寶瀅persil': 60,
#          'persil': 17,
#          'hilltop山頂鳥': 21,
#          'make up for ever': 25,
#          'wild calling': 10,
#          'kumnong': 3,
#          'orion': 46,
#          'loshi': 31,
#          '樂絲 loshi': 2,
#          'k-swiss': 51,
#          'estée lauder 雅詩蘭黛': 192,
#          'parodontax 牙周適': 79,
#          '牛頭牌 buffalo': 19,
#          '喵洽普 plan cat': 3,
#          '芯之麗 sublimic': 9,
#          'mk lab': 5,
#          "dentiste'牙醫選": 14,
#          'oxy': 7,
#          '貓皇族 king wang': 9,
#          '易生絲 essehair': 6,
#          '清水 shimizu': 50,
#          "l'occitane 歐舒丹": 105,
#          "歐舒丹 l'occitane": 7,
#          'aronyx': 10,
#          '荷蘭公主 princess': 11,
#          '特緹斯 twistix': 8,
#          '施華蔻 schwarzkopf': 36,
#          'algemarin': 5,
#          '歌林 kolin': 116,
#          '瑪宣妮 macherie': 19,
#          'eau 耀': 3,
#          '耀 eau': 8,
#          'eau耀': 46,
#          'powerbomb': 7,
#          'heinz亨式': 31,
#          'alpecin': 51,
#          '韓國422inc': 3,
#          'ghr健康主義': 3,
#          'ghr': 1,
#          '惠而浦 whirlpool': 53,
#          'dashing diva': 214,
#          'soto': 8,
#          'jacks': 6,
#          'freshel 膚蕊': 32,
#          '健康紀元 healthy era': 3,
#          '亞瑟士 asics': 93,
#          '統一ab': 92,
#          '統一 ab': 7,
#          'ettusais 艾杜紗': 134,
#          'yebisu': 26,
#          '博朗氏 balance': 9,
#          '愛樂薇 elle & vire': 20,
#          'bobbi brown 芭比波朗': 147,
#          'missha': 124,
#          'kose 高絲-專櫃': 11,
#          '岩谷 iwatani': 11,
#          'majolica majorca 戀愛魔鏡': 109,
#          '飛想茶 fuze tea': 21,
#          '原點 instinct': 47,
#          '雷馬 lexma': 20,
#          'a.h.c': 29,
#          '樂迪ld': 102,
#          'visee': 93,
#          '丹麥德瑪 derma': 13,
#          'derma': 2,
#          'derma 丹麥德瑪': 2,
#          '樂天 lotte': 19,
#          'lotte': 14,
#          'lotte樂天': 1,
#          '興波咖啡 simple kaffa': 6,
#          'petal fresh 沛特斯': 58,
#          '博帝 viper': 13,
#          'clinique 倩碧': 58,
#          'arctic': 9,
#          'kate tokyo 凱婷': 505,
#          'jealousness 婕洛妮絲': 8,
#          'doutor': 6,
#          '米森 vilson': 77,
#          'switch': 175,
#          'lits 日本植物精粹極緻奢華保養': 14,
#          'from taiwan 豐台灣': 19,
#          't core': 1,
#          'omi 近江兄弟社': 19,
#          'naruko 牛爾親研': 37,
#          '法米納 farmina': 41,
#          'ph9.0': 25,
#          '三洋 sanlux': 50,
#          '台灣三洋 sanlux': 20,
#          'ahc': 151,
#          '竣寶 gimpet': 7,
#          'queen bee 蜂王': 3,
#          'argelan': 19,
#          'c-skin 杜克': 1,
#          'amida': 21,
#          '慧心貓糧 smartheart': 6,
#          '慧心 smartheart': 34,
#          'tom ford': 25,
#          '貓戀人 honey cat': 4,
#          '廣鼎 intopic': 35,
#          "q'her 植感": 25,
#          'vaseline 凡士林': 116,
#          '植村秀 shu uemura': 176,
#          'shu uemura 植村秀': 17,
#          'farm stay': 20,
#          'evita 艾薇塔': 16,
#          'lotto': 73,
#          'sexylook 西西露': 48,
#          'uno': 48,
#          'helena rubinstein 赫蓮娜': 13,
#          '夏普 sharp': 52,
#          'kao 花王': 4,
#          '花王 kao': 85,
#          '花王kao': 3,
#          'ciao': 150,
#          'unlabel': 10,
#          'h2o': 31,
#          'unny club': 13,
#          '法麗 cherie': 8,
#          'dyson': 126,
#          '戴森 dyson': 17,
#          '捷森 jason': 21,
#          'vana candles 琺鈉': 5,
#          'chanel 香奈兒': 225,
#          '西雅圖 barista': 56,
#          '索尼 sony': 28,
#          'sony': 17,
#          'asahi': 120,
#          'asahi 朝日': 10,
#          'crest': 87,
#          '漁極 akika': 4,
#          'energy 艾諾琪': 4,
#          '福壽 fuso': 8,
#          '芮可 rico': 34,
#          'lb': 16,
#          'cnp laboratory': 5,
#          'esfolio': 6,
#          'fila': 171,
#          '耐嘉 kinyo': 45,
#          'haglofs': 2,
#          '可口可樂 coca cola': 220,
#          '紐崔克 natureke': 27,
#          'browit 貝奧莉': 18,
#          '微星科技 msi': 39,
#          'msi 微星': 35,
#          '微星 msi': 24,
#          'arcteryx 始祖鳥': 6,
#          '雷蛇 razer': 68,
#          "age20's": 15,
#          'yeaster': 14,
#          'lovita愛維他': 42,
#          'natures care': 2,
#          'zenn.th 茲恩': 38,
#          '優沛特 upet': 25,
#          'glinter': 8,
#          '天際線 horizon': 5,
#          '威德 weider': 11,
#          '桂格 quaker': 220,
#          'aibo': 16,
#          'kocskin 克麗詩黛': 1,
#          '直覺 sweet touch': 22,
#          'orbis 奧蜜思': 10,
#          '奧力棒 ozbone': 67,
#          '美津農 mizuno': 68,
#          '美津濃 mizuno': 27,
#          'robert timms': 4,
#          '倍思特 best': 3,
#          'valentino rudy 范倫鐵諾': 9,
#          '范倫鐵諾 valentino rudy': 1,
#          'happycall': 23,
#          'kangaroos': 34,
#          '斑馬牌 zebra ': 25,
#          'viridis virus': 5,
#          '汰漬 tide': 25,
#          'tide': 6,
#          '多芬 dove': 113,
#          'dove 多芬': 48,
#          '惠普 hp': 17,
#          'hp 惠普': 22,
#          '櫻花 sakura': 17,
#          '狼蛛 aula': 11,
#          '狐鐳 foxxray': 55,
#          'garmin': 44,
#          "喵樂 m'daryn": 12,
#          'etude house': 168,
#          'ozawakei': 7,
#          '偉嘉 whiskas': 74,
#          '可利亞 kria': 1,
#          '綠的 green': 5,
#          'green 綠的': 12,
#          '綠的green': 3,
#          'too cool for school': 79,
#          'sweets sweets': 13,
#          'duo 麗優': 14,
#          'e-power': 12,
#          'bloody': 4,
#          'haken': 1,
#          '伊克萊 egekilde': 6,
#          'rohto 樂敦': 77,
#          'rohto 日本樂敦': 13,
#          'gold suite': 3,
#          'bifesta 碧菲絲特': 169,
#          'glysomed': 17,
#          'ronever': 3,
#          'beauty buffet 天天美麗': 45,
#          'the ordinary': 29,
#          '東芝 toshiba': 45,
#          'sulwhasoo 雪花秀': 8,
#          'therapind 魔唇': 14,
#          'ysl 聖羅蘭': 127,
#          'jmsolution': 23,
#          '耐吉斯 solution': 48,
#          'vt cica': 35,
#          'meishoku 明色': 23,
#          'honeysuckle': 37,
#          'doggyman': 61,
#          'hoi': 4,
#          '愛思 is': 4,
#          'wadakan': 1,
#          'r.q.polo': 3,
#          'lacroix': 8,
#          'vivo': 35,
#          '韓國歐紳 osner': 1,
#          'sher 夏爾保養': 3,
#          'simple 清妍': 48,
#          'eunyul': 73,
#          'goodies': 19,
#          'mr&miss': 1,
#          'lechat': 28,
#          'unt': 102,
#          '台塑生醫forte': 11,
#          '自然物語 nature story': 3,
#          'yamaki': 11,
#          'oppo': 44,
#          'key coffee': 8,
#          'j-lin': 4,
#          'tokyu hands 台隆手創館': 15,
#          'tescom': 76,
#          'flexin': 2,
#          '愛喜雅 aixia': 27,
#          'jo malone': 23,
#          'foramen': 3,
#          'tgc': 5,
#          'udilife': 7,
#          'calypso': 2,
#          'the face shop菲詩小舖': 3,
#          'the face shop 菲詩小舖': 5,
#          'velcos': 11,
#          'clarins 克蘭詩': 34,
#          'lion kirei-kirei 日本獅王趣淨': 3,
#          'etude奧斯卡': 32,
#          '亞米亞米 yami yami': 15,
#          'shirmeny 雪曼妮': 3,
#          '海盜船 corsair': 29,
#          '3m': 76,
#          'rosy rosa': 20,
#          'atake': 4,
#          '寵物健康 wellness': 23,
#          'wellness': 2,
#          'pony': 12,
#          '日立 itachi': 34,
#          'dr.jart+': 23,
#          'jeogseoul 漢城淨雪': 7,
#          'de buyer': 5,
#          'heum': 3,
#          'aroma zone': 3,
#          'pupa': 2,
#          'kent': 2,
#          '肯特 kent': 4,
#          'osim': 7,
#          '努特 nuit': 6,
#          'nuit 努特': 4,
#          'opera': 18,
#          '明基 benq': 27,
#          'dr.wu 達爾膚': 204,
#          'teapower 茶寶': 2,
#          'absolute new york 絕色紐約': 48,
#          '希翠斯 citrus': 3,
#          'plantur 39': 11,
#          '歐克威爾 oh-care': 2,
#          'clio 珂莉奧': 115,
#          'clé de peau beauté 肌膚之鑰': 17,
#          'sole': 3,
#          'kissdiamond': 15,
#          '熊寶貝 snuggle': 57,
#          'uzu': 17,
#          '第一饗宴 firstmate': 8,
#          '摩卡 mocca': 44,
#          'collagen by watsons': 7,
#          'e視界': 11,
#          '樂扣樂扣 locknlock': 43,
#          '力保美達 lipovitan': 7,
#          'catfeet': 11,
#          '360': 1,
#          'enne': 6,
#          '卡氛 kafen': 30,
#          '飛柔 pert': 89,
#          'pro plan 冠能': 14,
#          '伊崎 ikiiki': 4,
#          'dr.satin': 44,
#          'vt cosmetics': 5,
#          'bladez': 9,
#          '統一lp33': 38,
#          'lp33': 9,
#          '紅牛 red cow': 45,
#          'lg bamboo salt': 29,
#          "i'nesvia": 2,
#          'vitantonio': 3,
#          'anessa 安耐曬': 18,
#          'mirae 未來美': 47,
#          '理想 perfect': 36,
#          '美士 nutro': 42,
#          '猋 pure': 4,
#          'pure': 16,
#          'pure純戀': 1,
#          '純戀 pure': 1,
#          'g7': 24,
#          '思波綺 tsubaki': 48,
#          "pet's love": 18,
#          '絲蘊 syoss': 38,
#          'syoss 絲蘊': 1,
#          '海爾 haier': 36,
#          '貓倍麗 monpetit': 41,
#          'nuk': 18,
#          '愛樂齒 ora2': 63,
#          'neoflam': 21,
#          '麗克特 récolte': 7,
#          '麗克特 recolte': 8,
#          "palmer's 帕瑪氏": 24,
#          "帕瑪氏 palmer's": 1,
#          '御衣坊 akira': 15,
#          'akira御衣坊': 5,
#          'pure.tiful 純淨妍': 1,
#          'isana': 11,
#          'isana 伊薩娜': 5,
#          'gw': 9,
#          '土耳其e.s.t.': 4,
#          'n.a.f': 9,
#          'suuen': 1,
#          'moonlight': 4,
#          'vichy 薇姿': 14,
#          'vichy薇姿': 2,
#          '歐萊德 oright': 27,
#          'tt kotemein tt 波特嫚': 12,
#          '凱瑞克 kalorik': 2,
#          'pink by pure beauty': 11,
#          '大同 tatung': 91,
#          'takumi': 9,
#          '塔谷米 takumi': 2,
#          'hyperx': 14,
#          'ttm 提提研': 30,
#          'fees 法緻': 3,
#          'fees': 4,
#          '法緻 fees': 1,
#          'cosnature 德國植萃': 6,
#          'optimum': 2,
#          '惠百施 ebisu': 61,
#          '香草集 justherb': 5,
#          'justherb': 2,
#          'justherb 香草集': 1,
#          'u beauty 澳洲依美油': 2,
#          '雀巢 nestle': 10,
#          '雷柏 rapoo': 10,
#          'vita': 6,
#          'rausch': 3,
#          'the north face': 37,
#          'bokbok': 4,
#          'hanskin': 2,
#          'kai 貝印': 3,
#          '藍帶 lv primeblue': 10,
#          '3ce': 16,
#          'lapetz 樂倍': 10,
#          "hunt's": 7,
#          '多益得all clean': 4,
#          '普洛斯prosi': 26,
#          '普洛斯 prosi': 19,
#          'flormar': 35,
#          '奇美 chimei': 80,
#          'uni water': 20,
#          'acer 宏碁': 102,
#          '宏碁 acer': 2,
#          'tsuvimi': 2,
#          'mildskin 麥德絲肌': 5,
#          'catuna': 12,
#          '奇妮 gennies': 2,
#          'cerave 適樂膚': 34,
#          'cerave適樂膚': 11,
#          '斐濟 fiji': 9,
#          'flowfushi': 5,
#          '綠野鮮食 health extension': 5,
#          '綠野鮮食health extension': 1,
#          '福壽 fuso pets': 3,
#          'bebe poshe 奢華寶貝': 7,
#          '森歐黎漾 saholea': 27,
#          'saholea': 5,
#          '健納緹 get naked': 4,
#          'swissvita 薇佳': 57,
#          'isleaf': 29,
#          '瑞軒 amtran': 5,
#          'jojome': 1,
#          'premiumcare': 5,
#          '卡薩 casa': 4,
#          'casa': 7,
#          '舊街場 oldtown': 26,
#          '花仙子 farcent': 41,
#          'farcent': 38,
#          'mlb': 16,
#          '伊藤園 ito en': 60,
#          'aiken': 11,
#          'aiken 艾肯': 5,
#          '艾肯 aiken': 1,
#          "l'egere 蘭吉兒": 19,
#          'dailix': 8,
#          'neuve 惹我': 26,
#          '巴絲特 baster': 8,
#          '活力零食 gootoe': 6,
#          'aveda': 24,
#          'aveda 肯夢': 6,
#          '恩荷 enherb': 2,
#          'combi 康貝': 1,
#          'combi': 2,
#          '康貝 combi': 1,
#          'irobot': 31,
#          'e.dot': 2,
#          'sapporo': 36,
#          '貝親 pigeon': 17,
#          'pigeon貝親': 9,
#          'laneige 蘭芝': 19,
#          '宏晉 hong jin': 16,
#          'htc': 15,
#          'jigott': 5,
#          'econeco 繪子貓': 11,
#          'delta': 4,
#          'marusan 丸三': 12,
#          'three': 35,
#          '八道 paldo': 70,
#          '伊絲婷 elastine': 43,
#          '虎牌 tiger': 20,
#          'kiki': 38,
#          'roudye 柔蝶': 24,
#          '柔蝶 roudye': 2,
#          'timaru 堤瑪露': 33,
#          'tabasco': 6,
#          'siroca': 11,
#          '盛源 shengyuan': 1,
#          '托斯卡 tuscan natural': 2,
#          "嬌生 johnson's": 37,
#          "johnson's 嬌生": 19,
#          'fresa': 1,
#          '美心 masions': 16,
#          '健康時刻 chewy time': 25,
#          'ts': 13,
#          '艾沛 ipet': 17,
#          '艾芮克 i-rocks': 42,
#          'target pro': 7,
#          '艾富鮮 a freschi srl': 5,
#          'df美肌醫生': 7,
#          'ehrmann': 25,
#          'cocodor': 55,
#          '思美洛ice': 7,
#          'sukin': 11,
#          'pharmaact': 8,
#          '可娜 kona': 1,
#          'caffè chat咖啡講': 6,
#          'skinlife': 38,
#          'mkup 美咖': 101,
#          'ido 船井醫朵保養': 7,
#          '麗仕 lux': 128,
#          '康寧 corningware': 24,
#          'maqpro': 11,
#          'maquillage': 43,
#          'psk 深海美肌專家': 7,
#          'psk 寶絲汀': 3,
#          'beautia 倍立雅': 6,
#          '阿葵亞 aquair': 55,
#          'saugella 賽吉兒': 2,
#          '富及第 frigidaire': 36,
#          '阿爾卡特 alcatel': 1,
#          'palladio': 53,
#          'uniqman': 2,
#          '旺德 wonder': 9,
#          'heartfelt': 6,
#          'oven-baked': 2,
#          'hiles': 4,
#          'sabon': 18,
#          '咪碼 mimar': 12,
#          'minon aminomoist 蜜濃': 35,
#          'breeza': 1,
#          'el伊德爾': 8,
#          'patto': 3,
#          'boneplus': 24,
#          'maycheer 美茜兒': 1,
#          'maycheer': 2,
#          'annemarie borlind 安娜柏林': 1,
#          "l'oréal paris 巴黎萊雅": 17,
#          "巴黎萊雅 l'oreal paris": 34,
#          'r.o.c.s': 3,
#          '克寧 klim': 75,
#          'vosun': 2,
#          'pelican 沛麗康': 9,
#          '沛麗康 pelican': 1,
#          'siegal 思高': 36,
#          '歐瑞 yarrah': 1,
#          'hau sanh': 2,
#          'woman method': 1,
#          '丹 dan': 9,
#          'belle madame 貝麗瑪丹': 8,
#          'nature tree': 3,
#          'simple life': 9,
#          'naive 娜艾菩': 7,
#          '娜艾菩naive': 8,
#          'pure mind': 6,
#          'elixir 怡麗絲爾': 48,
#          '人因科技 ergotech': 8,
#          'dream trend 凱夢': 9,
#          '凱夢 dream trend': 1,
#          '舒味思 schweppes': 26,
#          '倍思 baseus': 11,
#          'wet n wild': 12,
#          'cath kidston': 1,
#          '自然癮食 addiction': 8,
#          'mdovia': 4,
#          'romand': 43,
#          '怪獸部落 litomon': 21,
#          'cherry': 29,
#          '華為 huawei': 25,
#          'embryolisse 恩倍思': 11,
#          'vacci': 5,
#          'timberland': 20,
#          'outdoorbase': 13,
#          '新肌霓 ingeni': 4,
#          'oster': 13,
#          '美國oster': 3,
#          '卡格 kakato': 1,
#          'revive 麗膚再生': 3,
#          'koyo': 1,
#          '逸萱秀 essentia': 38,
#          'targus': 9,
#          '科克蘭 kirkland signature': 24,
#          'kirkland signature 科克蘭': 3,
#          '日本 lishan': 4,
#          '歐斯恩 oceanique': 3,
#          '威比 wellbe': 7,
#          'berioska': 2,
#          'create dentfine': 8,
#          'darling': 8,
#          '完美日記 perfect diary': 3,
#          'rinpoo潤波': 22,
#          '優妹 u-may': 6,
#          'the body shop 美體小舖': 19,
#          'the body shop': 8,
#          '美體小舖 the body shop': 4,
#          'lescaut 蕾斯卡歐': 4,
#          'physiogel 潔美淨': 18,
#          '魔爪 monster energy': 49,
#          '森鮮 forest': 21,
#          'intex': 13,
#          'citycolor': 1,
#          '韓波俐 hanboly': 3,
#          '巴黎帕芬 parfum': 1,
#          'parfum': 2,
#          'tiss': 19,
#          '台菱 paddy': 1,
#          'colourpop': 2,
#          '奧藍多 allando': 8,
#          'natural balance': 20,
#          'iris': 22,
#          'guerisson': 3,
#          'phisoderm 菲蘇德美': 28,
#          'gigabyte 技嘉': 16,
#          '技嘉 gigabyte': 8,
#          'pri': 33,
#          '愛惠浦 everpure': 2,
#          'op': 17,
#          'profusion': 35,
#          'avila': 13,
#          '愛恩富 anf': 7,
#          'cooler master': 24,
#          'honey': 3,
#          '康定 contin': 22,
#          '美洲獅cougar': 2,
#          'mustela 慕之恬廊': 26,
#          '慕之恬廊 mustela': 5,
#          'mustela': 1,
#          'lebelage': 13,
#          'yubico': 41,
#          'naturehike': 9,
#          'kangol': 24,
#          '袋鼠 kangol': 2,
#          'fzc': 11,
#          'man-q': 9,
#          'allegrini': 3,
#          'sputnik 史普尼克': 2,
#          'lenovo 聯想': 41,
#          '聯想 lenovo': 37,
#          '沙宣 vs': 15,
#          'freeplus 芙莉思': 19,
#          'orihiro': 1,
#          'nicka.k': 1,
#          'frudia': 6,
#          '德國達麗dalli': 37,
#          '德國達麗 dalli': 1,
#          'pg美人網': 3,
#          'junkisei prime 潤肌精': 49,
#          '三菱 mitsubishi': 30,
#          '巴西里亞 brasilia': 2,
#          'wildkin': 1,
#          'love code 戀愛密碼': 13,
#          'k.c.dog': 16,
#          '九陽 joyoung': 9,
#          '饗食 peter': 1,
#          '好味小姐 lady flavor': 10,
#          'lucky': 12,
#          '嬌聯 unicharm': 19,
#          '豐力富 fernleaf': 33,
#          'new beads': 9,
#          '東洋qtta': 2,
#          'opal 澳寶': 6,
#          'j.gasco': 2,
#          'mega harvest': 4,
#          'ifit 微卡': 19,
#          'muji 無印良品': 29,
#          '無印良品 muji': 20,
#          'the public organic': 12,
#          'haru': 4,
#          '日本toffy': 2,
#          'toffy': 7,
#          '歐芮坦orita': 3,
#          't.c.star': 23,
#          'pon pon man 澎澎man': 37,
#          'opi': 6,
#          '綠藤生機 greenvines': 13,
#          'miyoshi': 5,
#          'miyoshi 家族石鹼': 4,
#          '玉之肌 miyoshi': 3,
#          '蔻蘿蘭 klorane': 47,
#          'fuji': 11,
#          '奇拉 keyra': 3,
#          '咪歐 me-o': 48,
#          'corsica 科皙佳': 1,
#          'corsica': 1,
#          'xbox': 4,
#          'baan 貝恩': 12,
#          'baan': 2,
#          'derma&more': 2,
#          'mistine': 14,
#          'darphin 朵法': 10,
#          '艾黎亞 anriea': 4,
#          '優生 us baby': 9,
#          '樂透 beaphar': 12,
#          'deary 媞爾妮': 7,
#          'deary': 2,
#          '媞爾妮 deary': 1,
#          'handme': 32,
#          '紐健士 supreme source': 2,
#          'qundo 康朵': 4,
#          '康芙麗 comefree': 2,
#          '德國冰豹roccat': 6,
#          'kenwood': 1,
#          'agf': 18,
#          'atrix 艾翠斯': 20,
#          'kiss': 13,
#          '大河 taiga': 6,
#          'taiga': 1,
#          'mylk': 2,
#          '博寶兒probo': 8,
#          '博寶兒 probo': 13,
#          'probo 博寶兒': 2,
#          'mei': 25,
#          'rimmel 倫敦芮魅': 38,
#          '唯潔 whimzees': 6,
#          'clover': 14,
#          'eilles': 2,
#          'lucido 倫士度': 6,
#          '倫士度 lucido': 4,
#          'akvile': 2,
#          'la lune 蘭韻': 1,
#          'a-star bones': 28,
#          'alkmene 歐坷蔓': 2,
#          '歐坷蔓 alkmene': 1,
#          'aqua label 水之印': 32,
#          'zettoc': 7,
#          'dydo 吟麗': 5,
#          'dydo': 4,
#          '美亞 meyer': 30,
#          "dr. bronner's 布朗博士": 6,
#          '娜奧now': 8,
#          'now 娜奧': 1,
#          'now娜奧': 1,
#          'skinfood 思親膚': 18,
#          '名象 min shiang': 11,
#          'medi flower': 6,
#          'saraya': 4,
#          '諾鈣c': 4,
#          "美喵人生 o'kat": 2,
#          '維齊 vi.chi': 27,
#          'iroka': 6,
#          'blackmores 澳佳寶': 6,
#          'blackmores澳佳寶': 3,
#          'natural lady': 2,
#          '11益生菌': 3,
#          '卡比 canidae': 7,
#          'combo': 2,
#          'tiddi': 3,
#          '歐恩 on': 1,
#          'ferrarelle': 3,
#          'g&m': 4,
#          'nuxe 黎可詩': 12,
#          'nuxe 巴黎歐樹': 3,
#          'kitcat': 5,
#          'pair 沛醫亞': 18,
#          'friskies': 5,
#          'flair': 4,
#          'barrier repair': 6,
#          'the orchid skin': 9,
#          'joajota': 4,
#          'ac makeup': 5,
#          'kneipp 克奈圃': 4,
#          '克奈圃 kneipp': 2,
#          '3q': 4,
#          'aesop': 23,
#          '日清 nissin': 7,
#          'blistex 碧唇': 19,
#          'nuby': 11,
#          'momus': 6,
#          'bevy c.': 5,
#          '芬達 fanta': 27,
#          'teteo': 5,
#          'ipsa 茵芙莎': 13,
#          'andzen': 22,
#          '義大利balzano': 2,
#          'balzano': 4,
#          '歐森 awson': 1,
#          'aprilskin': 9,
#          'lotus': 3,
#          '大拇指 fp': 2,
#          'mandom': 9,
#          'delux': 10,
#          'nicoh': 10,
#          'softymo 絲芙蒂': 16,
#          'suntory 三得利': 5,
#          '三得利 suntory': 1,
#          '德國雙人 zwilling': 13,
#          'desiam暹羅': 2,
#          'userism': 3,
#          'k&k': 1,
#          'banila co': 8,
#          '威技牌 new widetech': 21,
#          'tarn ju': 11,
#          'hb': 1,
#          '維吉 vegepet': 8,
#          'shower mate': 13,
#          'unidus': 16,
#          'granarolo': 3,
#          'dr pepper': 9,
#          'giorgio armani 亞曼尼': 58,
#          'giorgio armani': 1,
#          'genie 瓶中精靈': 1,
#          'ecologic': 1,
#          ...})

# %%
# Train test split
brand_training, brand_testing = train_test_split(brand_train, test_size=0.2, random_state=42)
brand_training
# Out:
#           id                                             name  \
# 14522  14522                   097855152251羅技k580超薄跨平台藍芽鍵盤珍珠白
# 59818  59813                              雪山啤酒330ml*6入l]
# 33677  33677                                         sk惹我眉筆gy
# 36232  36232  coolermaster酷碼cmck350rgb機械式鍵盤電競鍵盤青軸茶軸紅軸酷媽[免運速出]
# 35438  35438                                 凱夢持霧零瑕粉底液-m01白皙色
# ...      ...                                              ...
# 37195  37195                               紐健士無穀犬糧牛肉+蔬果[260g]
# 6266    6266                        heme柔霧慕斯唇釉-05wildrose45ml
# 54889  54887                                          澎澎淨化沐浴乳
# 860      861                                妮維雅潤彩護唇膏~甜美粉紅2.4g
# 15796  15796                        (e)onecat頂級成貓化毛/毛球控制1.5kg
#
#                     brand                                     clean_name  \
# 14522         羅技 logitech                             羅技k580超薄跨平台藍芽鍵盤珍珠白
# 59818                  雪山                                           雪山啤酒
# 33677            neuve 惹我                                       sk惹我眉筆gy
# 36232       cooler master  coolermaster酷碼cmck350rgb機械式鍵盤電競鍵盤青軸茶軸紅軸酷媽免運速出
# 35438      dream trend 凱夢                               凱夢持霧零瑕粉底液-m01白皙色
# ...                   ...                                            ...
# 37195  紐健士 supreme source                                    紐健士無穀犬糧牛肉蔬果
# 6266                 heme                          heme柔霧慕斯唇釉-05wildrose
# 54889                  澎澎                                        澎澎淨化沐浴乳
# 860             nivea 妮維雅                                   妮維雅潤彩護唇膏甜美粉紅
# 15796           希爾思 hills                              eonecat頂級成貓化毛毛球控制
#
#              clean_brand
# 14522         羅技logitech
# 59818                 雪山
# 33677            惹我neuve
# 36232      cooler master
# 35438      凱夢dream trend
# ...                  ...
# 37195  紐健士supreme source
# 6266              喜蜜heme
# 54889  澎澎pon pon man man
# 860             妮維雅nivea
# 15796           希爾思hills
#
# [56031 rows x 5 columns]

# %%
brand_training.to_csv('/content/drive/MyDrive/碩一下/金融科技/麻布數據/資料檔/brand_train.csv', index=False)
brand_testing.to_csv('/content/drive/MyDrive/碩一下/金融科技/麻布數據/資料檔/brand_test.csv', index=False)
